# %%
import cv2
import tensorflow as tf
import os
import numpy as np
import network as net
import json
from Training import openpose
import matplotlib.pyplot as plt
from scipy.ndimage.filters import maximum_filter
import math
from collections import Counter, defaultdict
import itertools
import matplotlib as mpl
import time
import ast
from scipy.ndimage.filters import gaussian_filter
import matplotlib
# Out:
# C:\Users\JAEKYU\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Open Pose Class Loading Finish

# %%
class NumpyEncoder(json.JSONEncoder):
    """ Special json encoder for numpy types """
    def default(self, obj):
        if isinstance(obj, (np.int_, np.intc, np.intp, np.int8,
            np.int16, np.int32, np.int64, np.uint8,
            np.uint16, np.uint32, np.uint64)):
            return int(obj)
        elif isinstance(obj, (np.float_, np.float16, np.float32, 
            np.float64)):
            return float(obj)
        elif isinstance(obj,(np.ndarray,)): #### This is the fix
            return obj.tolist()
        return json.JSONEncoder.default(self, obj)

# %%
def make_inspection_batch(batch_size = 1):
    video_path = './video_with_abstacle/TrainingSet_2/video_another_30'
    anno_path = './video_with_abstacle/TrainingSet_2/video_another_30_annotaion'
    
    video_list = os.listdir(video_path)
    anno_list = os.listdir(anno_path)
    
    video_list.sort()
    anno_list.sort()
    
    num_of_data = len(video_list)
    index = np.arange(0, num_of_data)
    
    video_path = [video_path +'/'+ video_list[i] for i in index]
    anno_path = [anno_path +'/'+ anno_list[j] for j in index]
    #print("test video : ",shuffled_video_path)
    return np.asarray(video_path), np.asarray(anno_path)
def make_test_batch(img_path, batch_size):
    num_of_data = len(img_path)
    index = np.arange(0, num_of_data)
    np.random.shuffle(index)
    index = index[:batch_size]
    
    shuffled_img_data = [img_path[i] for i in index]
    
    return np.asarray(shuffled_img_data)

def path_to_image(img_path, batch_size):
    #buffer 선언
    image_data = np.zeros((batch_size, 356, 356, 3), np.uint8)
    
    index = 0
    for img in (img_path):
        image_data[index] = cv2.imread(img)
        index = index + 1;

    return image_data

def load_test_data(save_path):
    img_path = save_path#"./MPII_Dataset/resized_test_image/"
    file_path = []
    file_list = os.listdir(img_path)
    for i in (file_list):
        file_path.append(img_path + i)
    return file_path

def padRightDownCorner(img, stride, padValue):
    h = img.shape[0]
    w = img.shape[1]

    pad = 4 * [None]
    pad[0] = 0 # up
    pad[1] = 0 # left
    pad[2] = 0 if (h%stride==0) else stride - (h % stride) # down
    pad[3] = 0 if (w%stride==0) else stride - (w % stride) # right

    img_padded = img
    pad_up = np.tile(img_padded[0:1,:,:]*0 + padValue, (pad[0], 1, 1))
    img_padded = np.concatenate((pad_up, img_padded), axis=0)
    pad_left = np.tile(img_padded[:,0:1,:]*0 + padValue, (1, pad[1], 1))
    img_padded = np.concatenate((pad_left, img_padded), axis=1)
    pad_down = np.tile(img_padded[-2:-1,:,:]*0 + padValue, (pad[2], 1, 1))
    img_padded = np.concatenate((img_padded, pad_down), axis=0)
    pad_right = np.tile(img_padded[:,-2:-1,:]*0 + padValue, (1, pad[3], 1))
    img_padded = np.concatenate((img_padded, pad_right), axis=1)

    return img_padded, pad

# %%
#f = open("./Video_annotation/1.txt", 'w')
def demo_view(oriImg, input_heatmap, input_paf):
    #input_heatmap = np.squeeze(input_heatmap)
    heatmap_avg = np.zeros((oriImg.shape[0], oriImg.shape[1], 17))
    paf_avg = np.zeros((oriImg.shape[0], oriImg.shape[1], 34))

    
    heatmap_avg = heatmap_avg + input_heatmap
    paf_avg = paf_avg + input_paf
    all_peaks = []
    peak_counter = 0

    for part in range(17-1):
        map_ori = heatmap_avg[:,:,part]
        map = gaussian_filter(map_ori, sigma=3)

        map_left = np.zeros(map.shape)
        #print(np.shape(map_left))
        map_left[1:,:] = map[:-1,:]
        map_right = np.zeros(map.shape)
        map_right[:-1,:] = map[1:,:]
        map_up = np.zeros(map.shape)
        map_up[:,1:] = map[:,:-1]
        map_down = np.zeros(map.shape)
        map_down[:,:-1] = map[:,1:]

        peaks_binary = np.logical_and.reduce((map>=map_left, map>=map_right, map>=map_up,\
                                              map>=map_down, map > 0.1))
        peaks = list(zip(np.nonzero(peaks_binary)[1], np.nonzero(peaks_binary)[0])) # note reverse
        peaks_with_score = [x + (map_ori[x[1],x[0]],) for x in peaks]
        id = range(peak_counter, peak_counter + len(peaks))
        peaks_with_score_and_id = [peaks_with_score[i] + (id[i],) for i in range(len(id))]

        all_peaks.append(peaks_with_score_and_id)
        peak_counter += len(peaks)


    connection_all = []
    special_k = []
    mid_num = 10###########################################################################################
    #paf_avg = resized_vectormap
    for k in range(len(mapIdx)):
        score_mid = paf_avg[:,:,[x-17 for x in mapIdx[k]]]
        #print("score_mid : ",np.shape(score_mid))
        candA = all_peaks[limbSeq[k][0]]#all_peaks[limbSeq[k][0]-1]#157
        candB = all_peaks[limbSeq[k][1]]#all_peaks[limbSeq[k][1]-1]#246
        #candA : [(182, 68, 0.8127860426902771, 9)]
        #candB :[(173, 92, 0.8721999526023865, 8)]
        #print("candA, candB : ",candA, candB)
        nA = len(candA)
        nB = len(candB)
        #print("nA, nB : ", nA, nB)
        indexA, indexB = limbSeq[k]
        #print("indexA, indexB : ", indexA, indexB)
        if(nA != 0 and nB != 0):
            connection_candidate = []
            for i in range(nA):
                for j in range(nB):
                    vec = np.subtract(candB[j][:2], candA[i][:2])
                    norm = math.sqrt(vec[0]*vec[0] + vec[1]*vec[1])
                    # failure case when 2 body parts overlaps
                    if norm == 0:
                        continue
                    vec = np.divide(vec, norm)

                    startend = list(zip(np.linspace(candA[i][0], candB[j][0], num=mid_num), \
                                   np.linspace(candA[i][1], candB[j][1], num=mid_num)))

                    vec_x = np.array([score_mid[int(round(startend[I][1])), int(round(startend[I][0])), 0] \
                                      for I in range(len(startend))])

                    vec_y = np.array([score_mid[int(round(startend[I][1])), int(round(startend[I][0])), 1] \
                                      for I in range(len(startend))])

                    score_midpts = np.multiply(vec_x, vec[0]) + np.multiply(vec_y, vec[1])
                    score_with_dist_prior = sum(score_midpts)/len(score_midpts) + min(0.5*oriImg.shape[0]/norm-1, 0)
                    #print("score_midpts : ", score_midpts)
                    criterion1 = len(np.nonzero(score_midpts > 0.0001)[0]) > 0.00005 * len(score_midpts)
                    #print("score_with_dist_prior : ", score_with_dist_prior)
                    criterion2 = score_with_dist_prior > 0.1
                    #print("criterion1, criterion2 : ", criterion1, criterion2)
                    if criterion1 and criterion2:
                        #print("1")
                        connection_candidate.append([i, j, score_with_dist_prior, score_with_dist_prior+candA[i][2]+candB[j][2]])
            #print("connection_candidate : ", connection_candidate)
            connection_candidate = sorted(connection_candidate, key=lambda x: x[2], reverse=True)
            connection = np.zeros((0,5))
            #print("connection_candidate : ", connection_candidate)
            for c in range(len(connection_candidate)):
                i,j,s = connection_candidate[c][0:3]
                if(i not in connection[:,3] and j not in connection[:,4]):
                    connection = np.vstack([connection, [candA[i][3], candB[j][3], s, i, j]])
                    if(len(connection) >= min(nA, nB)):
                        break
            #print("connection : ", connection)
            connection_all.append(connection)
        else:
            special_k.append(k)
            connection_all.append([])
    subset = -1 * np.ones((0, 20))######################################################
    candidate = np.array([item for sublist in all_peaks for item in sublist])
    for k in range(len(mapIdx)):
        if k not in special_k:
            partAs = connection_all[k][:,0]
            partBs = connection_all[k][:,1]
            indexA, indexB = np.array(limbSeq[k]) - 1

            for i in range(len(connection_all[k])): #= 1:size(temp,1)
                #print("hello")
                found = 0
                subset_idx = [-1, -1]
                for j in range(len(subset)): #1:size(subset,1):
                    if subset[j][indexA] == partAs[i] or subset[j][indexB] == partBs[i]:
                        subset_idx[found] = j
                        found += 1
                if found == 1:
                    j = subset_idx[0]
                    if(subset[j][indexB] != partBs[i]):
                        subset[j][indexB] = partBs[i]
                        subset[j][-1] += 1
                        subset[j][-2] += candidate[partBs[i].astype(int), 2] + connection_all[k][i][2]
                elif found == 2: # if found 2 and disjoint, merge them
                    j1, j2 = subset_idx
                    membership = ((subset[j1]>=0).astype(int) + (subset[j2]>=0).astype(int))[:-2]
                    if len(np.nonzero(membership == 2)[0]) == 0: #merge
                        subset[j1][:-2] += (subset[j2][:-2] + 1)
                        subset[j1][-2:] += subset[j2][-2:]
                        subset[j1][-2] += connection_all[k][i][2]
                        subset = np.delete(subset, j2, 0)
                    else: # as like found == 1
                        subset[j1][indexB] = partBs[i]
                        subset[j1][-1] += 1
                        subset[j1][-2] += candidate[partBs[i].astype(int), 2] + connection_all[k][i][2]

                # if find no partA in the subset, create a new subset
                elif not found and k < 17:
                    row = -1 * np.ones(20)
                    row[indexA] = partAs[i]
                    row[indexB] = partBs[i]
                    row[-1] = 2
                    row[-2] = sum(candidate[connection_all[k][i,:2].astype(int), 2]) + connection_all[k][i][2]
                    subset = np.vstack([subset, row])
    #print("end~",subset)
    # delete some rows of subset which has few parts occur
    deleteIdx = [];
    #print(subset)
    for i in range(len(subset)):
        #print(subset[i][-1])
        if subset[i][-1] < 1 or subset[i][-2]/subset[i][-1] < 0.3:
            deleteIdx.append(i)
            #print(i)
    subset = np.delete(subset, deleteIdx, axis=0)
    #print(subset)
    # visualize

    cmap = matplotlib.cm.get_cmap('hsv')

    canvas = oriImg#cv2.imread(oriImg) # B,G,R order
    #canvas = canvas[:, :, (2,1,0)]
    #print(all_peaks)########################################################################################
    #nms_joint.append(all_peaks)
    #all_peaks_file = ",".join(str(x) for x in all_peaks)
    #f.write(all_peaks_file)
    #f.write("\n")
    
    for i in range(16):
        rgba = np.array(cmap(1 - i/16. - 1./32))
        rgba[0:3] *= 255

        for j in range(len(all_peaks[i])):
            #print((all_peaks[i][j]))
            #x = all_peaks[i][j][3]
            #y = all_peaks[i][j][1]
            cv2.circle(canvas, all_peaks[i][j][0:2], 2, colors[i], thickness=-1)
            #cv2.circle(canvas, (x, y), 1, colors[i], thickness=-1)

    to_plot = cv2.addWeighted(oriImg, 0.3, canvas, 0.7, 0)


    # visualize 2# visual 
    stickwidth = 1

    for i in range(15):
        for n in range(len(subset)):
            index = subset[n][np.array(limbSeq[i])-1]
            #print("index : ", index)
            if -1 in index:
                continue
            #print("hello")
            cur_canvas = canvas.copy()
            Y = candidate[index.astype(int), 0]
            X = candidate[index.astype(int), 1]
            mX = np.mean(X)
            mY = np.mean(Y)
            length = ((X[0] - X[1]) ** 2 + (Y[0] - Y[1]) ** 2) ** 0.5
            angle = math.degrees(math.atan2(X[0] - X[1], Y[0] - Y[1]))
            polygon = cv2.ellipse2Poly((int(mY),int(mX)), (int(length/2), stickwidth), int(angle), 0, 360, 1)
            cv2.fillConvexPoly(cur_canvas, polygon, colors[i])
            canvas = cv2.addWeighted(canvas, 0.4, cur_canvas, 0.6, 0)
    return canvas[:,:,[2,1,0]]

# %%
limbSeq = [(9, 8), (8, 13), (8, 12), (8, 7), (12, 11), (11, 10), (13, 14), (14, 15), \
           (7, 6), (6, 3),  (3, 4),  (4, 5), (6, 2),   (2, 1),   (1, 0)]#16개 조인트, 15개 limb

mapIdx = [(16, 17), (18, 19), (20, 21), (22, 23), (28, 29), (30, 31), (24, 25), (26, 27), (32, 33), \
          (34, 35), (38, 39), (40, 41), (36, 37), (42, 43), (44, 45)]#x, y vectormap Pairs 24,25

colors = [[255, 0, 0], [255, 85, 0], [255, 170, 0], [255, 255, 0], [170, 255, 0], [85, 255, 0], [0, 255, 0], \
          [0, 255, 85], [0, 255, 170], [0, 255, 255], [0, 170, 255], [0, 85, 255], [0, 0, 255], [85, 0, 255], \
          [170, 0, 255], [255, 0, 255], [255, 0, 170], [255, 0, 85]]

# %%
img_width = 356
video_data_path = "./video_with_abstacle/TrainingSet_2/video_another_30/"
video_save_path = "./video_with_abstacle/TrainingSet_2/video_another_30_inspection/"
video_list = os.listdir(video_data_path)


for i, video in enumerate(video_list):
    video_list[i] = video_data_path + video

# %%
#len(video_list)
#(video_list) = video_list[1024:]

# %%
#(video_list)

# %%
with tf.Session() as sess:
#with tf.Session(config=tf.ConfigProto(device_count={'GPU': 0})) as sess:
    obj = openpose(batch_size=1, sess = sess)
    sess.run(tf.global_variables_initializer())
    SAVE_PATH = "C:/Users/JAEKYU/Documents/Jupyter Notebook/Open_Pose/Weight/Weight.ckpt"
    saver = tf.train.Saver()
    saver.restore(sess, SAVE_PATH)
    
    
    
    
    for index, video in enumerate(video_list):
        #cap = cv2.VideoCapture(0)
        print(video)
        print(index)
        file_name = video.replace('./video_with_abstacle/TrainingSet_2/video_another_30/', "")
        cap = cv2.VideoCapture(video)
        
        fourcc = cv2.VideoWriter_fourcc(*'XVID')
        out = cv2.VideoWriter(video_save_path + file_name, fourcc, 20.0, (356, 356))
        length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        print(length)
        for index_sub in range(60):
            ret, img_color = cap.read()
            if(ret == True):
                img_color = cv2.resize(img_color, (356, 356))
                try:
                    heatmap, vectormap = obj.demo_test([img_color])

                    heatmap = np.squeeze(heatmap)
                    vectormap = np.squeeze(vectormap)

                    resized_heatmap = np.zeros((17, 356, 356))
                    resized_vectormap = np.zeros((34, 356, 356))

                    heatmap = np.transpose(heatmap, (2,0, 1))#17,44,44
                    vectormap = np.transpose(vectormap, (2,0, 1))#34,44,44

                    for k in range(17):
                        resized_heatmap[k] = cv2.resize(heatmap[k], (356, 356))
                    for l in range(34):
                        resized_vectormap[l] = cv2.resize(vectormap[l], (356, 356))
                    resized_heatmap = np.transpose(resized_heatmap, (1,2, 0))
                    resized_vectormap = np.transpose(resized_vectormap, (1,2, 0))

                    output = demo_view(img_color, resized_heatmap, resized_vectormap)
                    out.write(output)#bgr#rgb
                except:
                    print("------------------------------------------------------")
                    print("error video")
                    print(video)
                    print(index)
                    print("------------------------------------------------------")

            if ret == False:
                continue
            output = output[...,::-1]
            cv2.imshow('bgr', output)
            #27 -> esc
            if cv2.waitKey(1) & 0xFF == 27:
                break
        #json_nms_joint = dict()
        
        cap.release()
        out.release()
        cv2.destroyAllWindows()
# Out:
# test data load start
# test data load finish
# open pose init complete
# INFO:tensorflow:Restoring parameters from C:/Users/JAEKYU/Documents/Jupyter Notebook/Open_Pose/Weight/Weight.ckpt
# ./video_with_abstacle/TrainingSet_2/video_another_30/0.avi
# 0
# 31
# ./video_with_abstacle/TrainingSet_2/video_another_30/1.avi
# 1
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/100.avi
# 2
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/101.avi
# 3
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/102.avi
# 4
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/103.avi
# 5
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/104.avi
# 6
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/105.avi
# 7
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/106.avi
# 8
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/107.avi
# 9
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/108.avi
# 10
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/109.avi
# 11
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/110.avi
# 12
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/111.avi
# 13
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/112.avi
# 14
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/113.avi
# 15
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/114.avi
# 16
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/115.avi
# 17
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/116.avi
# 18
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/117.avi
# 19
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/118.avi
# 20
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/119.avi
# 21
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/120.avi
# 22
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/121.avi
# 23
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/122.avi
# 24
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/123.avi
# 25
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/124.avi
# 26
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/125.avi
# 27
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/126.avi
# 28
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/127.avi
# 29
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/128.avi
# 30
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/129.avi
# 31
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/130.avi
# 32
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/131.avi
# 33
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/132.avi
# 34
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/133.avi
# 35
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/134.avi
# 36
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/135.avi
# 37
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/136.avi
# 38
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/137.avi
# 39
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/138.avi
# 40
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/139.avi
# 41
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/14.avi
# 42
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/140.avi
# 43
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/141.avi
# 44
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/142.avi
# 45
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/143.avi
# 46
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/144.avi
# 47
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/145.avi
# 48
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/146.avi
# 49
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/147.avi
# 50
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/148.avi
# 51
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/149.avi
# 52
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/15.avi
# 53
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/150.avi
# 54
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/155.avi
# 55
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/156.avi
# 56
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/16.avi
# 57
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/17.avi
# 58
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/18.avi
# 59
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/19.avi
# 60
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/2.avi
# 61
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/20.avi
# 62
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/21.avi
# 63
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/22.avi
# 64
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/23.avi
# 65
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/24.avi
# 66
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/25.avi
# 67
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/26.avi
# 68
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/27.avi
# 69
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/28.avi
# 70
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/29.avi
# 71
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/3.avi
# 72
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/30.avi
# 73
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/31.avi
# 74
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/32.avi
# 75
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/33.avi
# 76
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/34.avi
# 77
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/35.avi
# 78
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/36.avi
# 79
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/37.avi
# 80
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/38.avi
# 81
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/39.avi
# 82
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/4.avi
# 83
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/40.avi
# 84
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/41.avi
# 85
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/42.avi
# 86
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/43.avi
# 87
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/44.avi
# 88
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/45.avi
# 89
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/46.avi
# 90
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/47.avi
# 91
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/48.avi
# 92
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/49.avi
# 93
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/5.avi
# 94
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/50.avi
# 95
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/51.avi
# 96
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/52.avi
# 97
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/53.avi
# 98
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/54.avi
# 99
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/55.avi
# 100
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/56.avi
# 101
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/57.avi
# 102
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/58.avi
# 103
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/59.avi
# 104
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/6.avi
# 105
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/60.avi
# 106
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/61.avi
# 107
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/62.avi
# 108
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/63.avi
# 109
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/64.avi
# 110
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/65.avi
# 111
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/66.avi
# 112
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/67.avi
# 113
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/68.avi
# 114
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/69.avi
# 115
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/7.avi
# 116
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/70.avi
# 117
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/71.avi
# 118
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/72.avi
# 119
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/73.avi
# 120
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/74.avi
# 121
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/75.avi
# 122
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/76.avi
# 123
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/77.avi
# 124
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/78.avi
# 125
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/79.avi
# 126
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/80.avi
# 127
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/81.avi
# 128
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/82.avi
# 129
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/83.avi
# 130
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/84.avi
# 131
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/85.avi
# 132
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/86.avi
# 133
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/87.avi
# 134
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/88.avi
# 135
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/92.avi
# 136
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/93.avi
# 137
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/94.avi
# 138
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/95.avi
# 139
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/96.avi
# 140
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/97.avi
# 141
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/98.avi
# 142
# 30
# ./video_with_abstacle/TrainingSet_2/video_another_30/99.avi
# 143
# 30

# %%
video_data = os.listdir("./video_with_abstacle/TrainingSet_2/video_another_60/")

# %%
for index, data in enumerate(video_data):
    video_data[index] = "./video_with_abstacle/TrainingSet_2/video_another_60/" + data

# %%
for index, data in enumerate(video_data):
    cap = cv2.VideoCapture(data)
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if(length != 60):
        print(data)
